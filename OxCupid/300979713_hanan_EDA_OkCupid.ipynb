# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('profiles.csv')
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %% [markdown]
# here is a histogram of the ages of people

# %%
mpl.rc("figure", figsize=(25, 10))
sns.countplot(x='age',data=df)

# %% [markdown]
# Histogram of the ages by sex

# %%
mpl.rc("figure", figsize=(20, 10))
sns.countplot(x='age',hue='sex',data=df)

# %% [markdown]
# The number of drinks correlate with drugs

# %%
mpl.rc("figure", figsize=(20, 5))
sns.countplot(data=df,x='drinks',hue='drugs')

# %%
body_vs_diet = df.groupby(by=['body_type','diet']).count()['age'].unstack()
body_vs_diet.head()
# Out:
# diet            anything  halal  kosher  mostly anything  mostly halal  \
# body_type
# a little extra     280.0    1.0     2.0            841.0           5.0
# athletic          1307.0    2.0     NaN           3472.0          17.0
# average           1669.0    2.0     NaN           4413.0           8.0
# curvy              389.0    NaN     NaN           1123.0           2.0
# fit               1361.0    2.0     5.0           3745.0           7.0
#
# diet            mostly kosher  mostly other  mostly vegan  mostly vegetarian  \
# body_type
# a little extra            2.0          52.0          13.0               95.0
# athletic                 20.0         242.0          57.0              629.0
# average                  16.0         235.0          55.0              703.0
# curvy                     5.0          89.0          24.0              307.0
# fit                      14.0         226.0          84.0              958.0
#
# ...

# %%
sns.heatmap(body_vs_diet,cmap='viridis')

# %%
sns.barplot(data=df,x='height',y='sex')

# %% [markdown]
# Heatmap that shows there is some high relation between religion and location

# %%
religion_d = df.groupby(by=['religion','location']).count()['age'].unstack()
mpl.rc("figure", figsize=(30, 45))
sns.heatmap(religion_d,cmap='viridis')

# %% [markdown]
# Barplot of the high between men and women

# %%
mpl.rc("figure", figsize=(20, 20))
sns.barplot(data=df,x='height',y='diet',hue='sex')

# %%
mpl.rc("figure", figsize=(10, 5))
sns.countplot(data=df,x='smokes',hue='sex')

# %% [markdown]
# Boxplot of the distribution between highet and smoking

# %%
mpl.rc("figure", figsize=(10, 15))
sns.boxplot(data=df,x='height',y='smokes',hue='sex')
